# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Philosophy-underlying-program-design" data-toc-modified-id="Philosophy-underlying-program-design-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Philosophy underlying program design</a></span></li><li><span><a href="#Ryerson's-program" data-toc-modified-id="Ryerson's-program-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Ryerson's program</a></span><ul class="toc-item"><li><span><a href="#Characteristics-of-Ryerson's-program" data-toc-modified-id="Characteristics-of-Ryerson's-program-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Characteristics of Ryerson's program</a></span></li><li><span><a href="#Degree-requirements-and-course-content" data-toc-modified-id="Degree-requirements-and-course-content-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Degree requirements and course content</a></span></li></ul></li><li><span><a href="#Kaggle's-ML-and-DS-survey" data-toc-modified-id="Kaggle's-ML-and-DS-survey-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Kaggle's ML and DS survey</a></span><ul class="toc-item"><li><span><a href="#EDA-of-EDA-of-Kaggle-2018-ML-and-DS-survey" data-toc-modified-id="EDA-of-EDA-of-Kaggle-2018-ML-and-DS-survey-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>EDA of EDA of Kaggle 2018 ML and DS survey</a></span><ul class="toc-item"><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Read-files" data-toc-modified-id="Read-files-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Read files</a></span></li><li><span><a href="#Survey-questions" data-toc-modified-id="Survey-questions-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Survey questions</a></span></li></ul></li></ul></li><li><span><a href="#Big-data" data-toc-modified-id="Big-data-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Big data</a></span></li></ul></div>

# %% [markdown]
# ## Philosophy underlying program design
#
# This project is intended as a design proposal for a
#
# Data science is an interdisciplinary field that combines expertise from different technical and expert domains.

# %% [markdown]
# ## Ryerson's program
#
# [Ryerson University](https://www.ryerson.ca/graduate/datascience/) in Toronto is offering a MSc (Master of Science) program in Data Science and Analytics. This program is similar to what this project aims to design, so an analysis of Ryerson's program is required to improve the understanding of market and competition in DS and ML education. It could also offer insights into potential ways of facilitating DS and ML education.
#
# ### Characteristics of Ryerson's program
#
# (according to Program Director)
#
# * interdisciplinary design
# * both lecture-based and hands-on lab learning environments
# * improve decisions throughout an organization’s value chain
# * prescriptive analytics techniques
# * methods used in building such data-driven models
# * hands-on experience with analytics tools
# * program engages industry partners
# * access to extensive data in health care, software engineering, social media, services and finance

# %% [markdown]
# Program also engages industry partners, such as:
#
# * BM
# * St. Michael’s Hospital
# * Hospital for Sick Children
# * Microsoft Research
# * the Globe and Mail
# * Toronto Stock Exchange

# %% [markdown]
# The program also partners with [Vector Institute](https://vectorinstitute.ai) to provide an opportunity to [apply for scholarships](https://vectorinstitute.ai/aimasters/) for pursuing studies in AI.

# %% [markdown]
# ### Degree requirements and course content

# %% [markdown]
# The requirements for successful completion of Ryerson's MSc in Data Science and Analytics are:
#
# **Four (4) required courses**
#
# * DS 8001 **Designs of Algorithms and Programming for Massive Data**
#
#     * theory and design of algorithms for massively large amounts of data
#     * introduction to information retrieval, streaming algorithms and analysis of web searches and crawls
#
#
# * DS 8002 **Machine Learning**
#
#     * supervised and unsupervised learning
#     * statistical models, decision trees, clustering. Feature extraction. ANN. Reinforcement learning
#
#
# * DS 8003 **Management of Big Data and Big Data Tools**
#
#     * data management techniques for storing and analyzing very large amounts of data
#     * emphasis on columnar databases and Map Reduce
#
#
# * DS 8004 **Data Mining and Prescriptive Analysis**
#
#     * use data to recommend optimum course of action to achieve the optimum outcome
#     * formulate new products and services in a data driven manner
#     * data mining, computational techniques, optimization and stochastic optimization techniques
#
#
# 2. Two (2) elective courses
#
# 3. Two (2) seminar courses
#
# 4. Major Research Project

# %% [markdown]
# ## Kaggle's ML and DS survey

# %% [markdown]
# [At the end of 2018](https://www.kaggle.com/kaggle/kaggle-survey-2018), as in 2017, Kaggle conducted an industry-wide survey of the state of data science and machine learning. The survey was live for one week in October, and after cleaning the data, finished with 23,859 responses, a 49% increase over the results of 2017. This survey presents a comprehensive view of the current state of data science and machine learning.

# %% [markdown]
# According to Kaggle, the results include raw numbers about who is working with data, what’s happening with machine learning in different industries, and the best ways for new data scientists to break into the field. When the survey analysis challenge was rolled out on Kaggle, it was presented with an Exploratory Data Analysis (EDA), which is presented in the following section.

# %% [markdown]
# ### EDA of EDA of Kaggle 2018 ML and DS survey
#
# Original EDA code copied from [Kaggle](https://www.kaggle.com/paultimothymooney/2018-kaggle-machine-learning-data-science-survey) (plotting functions).

# %% [markdown]
# #### Import libraries

# %%
# Import Python packages
import numpy as np 
import pandas as pd 
import os
import math
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core import display as ICD
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
import warnings
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.max_colwidth', 0)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# #### Read files

# %%
base_dir = 'kaggle-survey-2018/'

fileName = 'multipleChoiceResponses.csv'
filePath = os.path.join(base_dir,fileName)
surveySchemaPath = os.path.join(base_dir,'SurveySchema.csv')
multipleChoicePath = os.path.join(base_dir,'multipleChoiceResponses.csv')


survey2_expanded = pd.read_csv(filePath) 
responsesOnly_expanded = survey2_expanded[1:]

surveySchema = pd.read_csv(surveySchemaPath)

multipleChoice = pd.read_csv(multipleChoicePath)

# %% [markdown]
# #### Survey questions
#
# Questions relevant to program design

# %%
survey2_expanded.iloc[0]
# Out:
# Time from Start to Finish (seconds)    Duration (in seconds)
# Q1                                     What is your gender? - Selected Choice
# Q1_OTHER_TEXT                          What is your gender? - Prefer to self-describe - Text
# Q2                                     What is your age (# years)?
# Q3                                     In which country do you currently reside?
# Q4                                     What is the highest level of formal education that you have attained or plan to attain within the next 2 years?
# Q5                                     Which best describes your undergraduate major? - Selected Choice
# Q6                                     Select the title most similar to your current role (or most recent title if retired): - Selected Choice
# Q6_OTHER_TEXT                          Select the title most similar to your current role (or most recent title if retired): - Other - Text
# ...

# %%
survey2_expanded.head()
# Out:
#   Time from Start to Finish (seconds)                                      Q1  \
# 0               Duration (in seconds)  What is your gender? - Selected Choice
# 1                                 710                                  Female
# 2                                 434                                    Male
# 3                                 718                                  Female
# 4                                 621                                    Male
#
#                                        Q1_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                             Q2                                         Q3  \
# 0  What is your age (# years)?  In which country do you currently reside?
# ...

# %% [markdown]
# ## Big data
#
# According to the [3-year report](https://www.ryerson.ca/content/dam/pbdi/PBDI-3Year-Report.pdf) from Ryerson's Privacy and Big Data Institute [(PBDI)](https://www.ryerson.ca/pbdi/), growth of scale and rate of change of modern data generating technologies, such as mobile data and Internet of Things (IoT), are staggering. Acceleration of Big Data created social and economic difficulties that are underlied by uncertainties and fragmentation, and require a deliberate approach.
#
# As data-driven processes are becoming central in all sectors and a range of platforms, **a host of issues emerge related to privacy, cybersecurity and big data**, such as:
#
# * identity theft/fraud
# * data breaches and leaks
# * ransomware
# * legality of phone searches by law enforcement
# * commercial data sharing and/or usage
# * personal data protection in the era of WikiLeaks
# * government spying
# * IoT device hacking
# * Canadian privacy in the current American political climate
# * net neutrality
# * autonomous vehicles
# * collection, storage and use of biomedical data
